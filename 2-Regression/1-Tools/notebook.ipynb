# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection

# %%
X, y = datasets.load_diabetes(return_X_y=True)
print(X.shape)
print(X[0])
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]

# %%
X = X[:, 2]
X = X.reshape((-1,1))

# %%
#This line splits the data into training and testing sets
X_train, X_test, y_train, y_test = model_selection.train_test_split(X,y, test_size =0.33)

#This line creates a linear regression model and fits it to the training data
model = linear_model.LinearRegression()
model.fit(X_train, y_train)

#This line makes predictions on the test data
y_pred = model.predict(X_test)

plt.scatter(X_test, y_test, color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.xlabel('Scaled Body Mass Index')
plt.ylabel('Disease Progression')
plt.title('A Graph Plot Showing Diabetes Progression against Scaled BMI')
plt.show()
